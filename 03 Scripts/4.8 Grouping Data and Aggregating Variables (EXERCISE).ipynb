# %% [markdown]
# # Contents in this notebook
# 1. Importing libraries and data
# 2. 4.8 Exercise (Aggregrating the data)

# %% [markdown]
# # Import Libraries

# %%
# Importing Libraries
import pandas as pd
import numpy as np
import os

# %%
# Defining Path
path = r'C:\Users\seann\Downloads\Career Foundry Tasks\12-08-22 Instacart Basket Analysis'

# %%
# Importing Orders Products Merged Data Set
ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ords_prods_merged_new.pkl'))

# %% [markdown]
# # 4.8 Exercise

# %%
ords_prods_merge = ords_prods_merge.drop(columns = ['_merge'])

# %%
# Create a subset
df = ords_prods_merge[:1000000]

# %%
df.shape
# Out:
# (1000000, 17)

# %%
df.head(10)
# Out:
#    order_id  user_id  amount_of_orders_made  order_day_of_week  \
# 0   2539329        1                      1                  2
# 1   2398795        1                      2                  3
# 2    473747        1                      3                  3
# 3   2254736        1                      4                  4
# 4    431534        1                      5                  4
# 5   3367565        1                      6                  2
# 6    550135        1                      7                  1
# 7   3108588        1                      8                  1
# 8   2295261        1                      9                  1
# 9   2550362        1                     10                  4
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                   999.0         196                  1
# 1                  7                    15.0         196                  1
# ...

# %%
# Aggregating Data

# %%
df.groupby('product_name')

# %%
df.groupby('department_id').agg({'amount_of_orders_made': ['mean']})
# Out:
#               amount_of_orders_made
#                                mean
# department_id
# 4                         18.825780
# 7                         17.472355
# 13                        17.993423
# 14                        19.246334
# 16                        19.463012
# 17                        11.294069
# 19                        19.305237
# 20                        17.599636

# %%
df.groupby('department_id')['amount_of_orders_made'].mean()
# Out:
# department_id
# 4     18.825780
# 7     17.472355
# 13    17.993423
# 14    19.246334
# 16    19.463012
# 17    11.294069
# 19    19.305237
# 20    17.599636
# Name: amount_of_orders_made, dtype: float64

# %%
df.groupby('department_id').agg({'amount_of_orders_made': ['mean', 'min', 'max']})
# Out:
#               amount_of_orders_made
#                                mean min max
# department_id
# 4                         18.825780   1  99
# 7                         17.472355   1  99
# 13                        17.993423   1  99
# 14                        19.246334   1  99
# 16                        19.463012   1  99
# 17                        11.294069   1  98
# 19                        19.305237   1  99
# 20                        17.599636   1  99

# %%
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['amount_of_orders_made'].transform(np.max)

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id  amount_of_orders_made  order_day_of_week  \
# 0   2539329        1                      1                  2
# 1   2398795        1                      2                  3
# 2    473747        1                      3                  3
# 3   2254736        1                      4                  4
# 4    431534        1                      5                  4
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                   999.0         196                  1
# 1                  7                    15.0         196                  1
# 2                 12                    21.0         196                  1
# 3                  7                    29.0         196                  1
# 4                 15                    28.0         196                  1
#
#    reordered product_name  aisle_id  department_id  prices    price_range_loc  \
# ...

# %%
ords_prods_merge.head(100)
# Out:
#     order_id  user_id  amount_of_orders_made  order_day_of_week  \
# 0    2539329        1                      1                  2
# 1    2398795        1                      2                  3
# 2     473747        1                      3                  3
# 3    2254736        1                      4                  4
# 4     431534        1                      5                  4
# ..       ...      ...                    ...                ...
# 95   3226575      360                      1                  5
# 96   1469869      377                      3                  5
# 97   1927023      387                      2                  4
# 98    858092      420                      4                  1
# 99    119314      420                      5                  3
#
#     order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                   8                   999.0         196                  1
# ...

# %%
pd.options.display.max_rows = None

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: loyalty_flag, dtype: int64

# %%
ords_prods_merge[['user_id', 'loyalty_flag', 'amount_of_orders_made']].head(60)
# Out:
#     user_id      loyalty_flag  amount_of_orders_made
# 0         1      New customer                      1
# 1         1      New customer                      2
# 2         1      New customer                      3
# 3         1      New customer                      4
# 4         1      New customer                      5
# 5         1      New customer                      6
# 6         1      New customer                      7
# 7         1      New customer                      8
# 8         1      New customer                      9
# 9         1      New customer                     10
# 10       15  Regular customer                     15
# 11       15  Regular customer                     17
# 12       15  Regular customer                     18
# 13       15  Regular customer                     21
# 14       15  Regular customer                     22
# 15       19      New customer                      2
# 16       19      New customer                      5
# ...

# %%
ords_prods_merge.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'ords_prods_merge_new_new.pkl'))

# %%
# Turning outliers into NaN (extra cleaning of data)
ords_prods_merge.loc[ords_prods_merge['prices'] >100, 'prices'] = np.nan
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9368\2969743768.py in <module>
#       1 # Turning outliers into NaN (extra cleaning of data)
# ----> 2 ords_prods_merge.loc[ords_prods_merge['prices'] >100, 'prices'] = np.nan
#
# NameError: name 'np' is not defined
